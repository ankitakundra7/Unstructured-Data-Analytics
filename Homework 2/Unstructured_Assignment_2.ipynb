# %% [markdown]
# # Assignment 2 - Beer Recommendation System

# %% [markdown]
# ### Group Members: Ohyoon Kwon (ok2364), Oluwaseun Ibitoye (oli63), Aditya Soni (as96926), Samuel Oh (io3279), Ambikha Maharaj (am84333), Ankita Kundra (ak44675)

# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import spacy
import en_core_web_lg
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import string
from collections import Counter
stop_words = stopwords.words('english') 
import io
import warnings
warnings.filterwarnings('ignore')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ohyoo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ohyoo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Task A - WebScraper.io
# Extract around 6K reviews using WebScraper.io

# %%
# read the CSV file
df = pd.read_csv('beer_data.csv')
df = df.drop(columns=['web-scraper-order', 'web-scraper-start-url', 'beer-href'])
df.head()
# Out:
#                                        beer  \
# 0                                     Aaron
# 1                           Mocha Wednesday
# 2  Mexican Cake - Maple Bourbon Barrel-Aged
# 3                         Saison Du Fermier
# 4                            Stickee Monkee
#
#                                       product_review
# 0  flipper2gv from Canada (QC)\n\n4.75/5  rDev +2...
# 1  Radcpa from Washington\n\n4.27/5  rDev -5.5%\n...
# 2  mothman from Minnesota\n\n4.69/5  rDev +2%\nlo...
# 3  REVZEB from Illinois\n\n4.35/5  rDev -4.8%\nlo...
# 4  gooddaydiablo from Texas\n\n4.6/5  rDev +2.4%\...

# %%
# clean the data - split product_review
df['product_review'] = df.product_review.str.split('\n\n', expand=False)

# %%
# extract ratings from product_review
lst = []
for i in range(len(df)):
    a = df.product_review[i][1].split('/')
    lst.append(a[0])
df['rating'] = lst
df.head()
# Out:
#                                        beer  \
# 0                                     Aaron
# 1                           Mocha Wednesday
# 2  Mexican Cake - Maple Bourbon Barrel-Aged
# 3                         Saison Du Fermier
# 4                            Stickee Monkee
#
#                                       product_review rating
# 0  [flipper2gv from Canada (QC), 4.75/5  rDev +2....   4.75
# 1  [Radcpa from Washington, 4.27/5  rDev -5.5%\nl...   4.27
# 2  [mothman from Minnesota, 4.69/5  rDev +2%\nloo...   4.69
# 3  [REVZEB from Illinois, 4.35/5  rDev -4.8%\nloo...   4.35
# 4  [gooddaydiablo from Texas, 4.6/5  rDev +2.4%\n...    4.6

# %%
# extracting review text
def get_review(s):
    a = ''.join(s[2:-1])
    return a

# %%
# final table
df['product_review'] = df['product_review'].apply(get_review)
beer_df = df[['beer','product_review','rating']]

# %%
beer_df
# Out:
#                                           beer  \
# 0                                        Aaron
# 1                              Mocha Wednesday
# 2     Mexican Cake - Maple Bourbon Barrel-Aged
# 3                            Saison Du Fermier
# 4                               Stickee Monkee
# ...                                        ...
# 6222                                     Bomb!
# 6223                           Mocha Wednesday
# 6224                           Emerald Grouper
# 6225                      Ghost In The Machine
# 6226                                Black Gold
#
#                                          product_review rating
# 0     A: Pours a deep murky brown color with a beige...   4.75
# 1     Brown appearance with slight tan head that dis...   4.27
# 2     Tan head but not a lot. Dark brown/black color...   4.69
# 3     Simplistic beauty is how I would describe this...   4.35
# 4     2018 vintage, tasted on 2021.1.11-------------...    4.6
# ...                                                 ...    ...
# 6222  Silky smooth texture. Rich flavors of coffee, ...   4.88
# 6223  2016 Vintage.Poured with quite a bit of sedime...   4.51
# 6224  Drank from a 1 pint, 6 fl. oz bottle purchased...   4.12
# 6225  Pours a hazed gold with a thumb of eggshell co...   4.13
# 6226  16, 17.Big barrel presence. Chocolate, fudge, ...   4.54
#
# [6227 rows x 3 columns]

# %%
beer_df.to_csv('beer.csv')

# %% [markdown]
# # Task B
# Word frequency analysis to find important attributes
# Assume that a customer has specified three attributes of the product as being important to him or her.

# %%
df = pd.read_csv('beer.csv')
df.head()
# Out:
#    Unnamed: 0                                      beer  \
# 0           0                                     Aaron
# 1           1                           Mocha Wednesday
# 2           2  Mexican Cake - Maple Bourbon Barrel-Aged
# 3           3                         Saison Du Fermier
# 4           4                            Stickee Monkee
#
#                                       product_review  rating
# 0  A: Pours a deep murky brown color with a beige...    4.75
# 1  Brown appearance with slight tan head that dis...    4.27
# 2  Tan head but not a lot. Dark brown/black color...    4.69
# 3  Simplistic beauty is how I would describe this...    4.35
# 4  2018 vintage, tasted on 2021.1.11-------------...    4.60

# %%
# Cleaning
df = df.drop(['Unnamed: 0'], axis=1)
df = df.dropna()

# renaming columns
df = df.rename({'beer':'product_name', 'rating':'user_rating'}, axis=1)

# %%
# removing punctuations, transforming everything to lowercase, and tokenizing
df['clean_review'] = df['product_review'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['clean_review'] = df['clean_review'].apply(lambda x: x.lower())
df['clean_review'] = df['clean_review'].apply(word_tokenize).apply(set).apply(list)

# removing stopwords
def remove_stopwords(s):
    return [w for w in s if not w in stop_words]

df['clean_review'] = df['clean_review'].apply(remove_stopwords)

# %%
# stitching the words into a corpus
def stitch_words(comment_col):
    corpus = []
    for words in comment_col:
        corpus += words
    return corpus
corpus = stitch_words(df['clean_review'])

# getting the word frequencies
word_freq = nltk.FreqDist(corpus)

# %%
# extracting the top frequencies
word_freq.most_common()
# Out:
# [('head', 3234),
#  ('beer', 2740),
#  ('taste', 2096),
#  ('one', 1657),
#  ('dark', 1652),
#  ('sweet', 1648),
#  ('like', 1604),
#  ('nose', 1594),
#  ('chocolate', 1588),
#  ('good', 1492),
#  ('pours', 1468),
#  ('carbonation', 1421),
#  ('nice', 1408),
#  ('well', 1380),
#  ('black', 1361),
#  ('body', 1360),
#  ('bottle', 1343),
#  ('light', 1316),
#  ('finish', 1316),
#  ('notes', 1277),
#  ('vanilla', 1276),
#  ('aroma', 1270),
#  ('mouthfeel', 1247),
#  ('white', 1246),
#  ('medium', 1213),
#  ('bit', 1195),
#  ('smooth', 1185),
#  ('flavor', 1160),
#  ('bourbon', 1158),
#  ('great', 1142),
#  ('color', 1136),
#  ('really', 1135),
#  ('fruit', 1134),
#  ('thick', 1128),
#  ('coffee', 1085),
#  ('little', 1081),
#  ('poured', 1081),
#  ('orange', 1053),
#  ('flavors', 1032),
#  ('overall', 1004),
#  ('brown', 998),
#  ('lacing', 982),
#  ('barrel', 976),
#  ('glass', 969),
#  ('oak', 940),
#  ('citrus', 939),
#  ('feel', 925),
#  ('bitterness', 913),
#  ('much', 881),
#  ('sweetness', 849),
#  ('’', 845),
#  ('creamy', 841),
#  ('smell', 820),
#  ('hazy', 813),
#  ('malt', 810),
#  ('dry', 792),
#  ('stout', 769),
#  ('full', 751),
#  ('caramel', 741),
#  ('balanced', 723),
#  ('big', 716),
#  ('still', 696),
#  ('best', 695),
#  ('rich', 680),
#  ('get', 679),
#  ('alcohol', 663),
#  ('thin', 654),
#  ('bitter', 651),
#  ('almost', 650),
#  ('slightly', 618),
#  ('would', 610),
#  ('pour', 608),
#  ('quite', 587),
#  ('bodied', 586),
#  ('tropical', 584),
#  ('grapefruit', 583),
#  ('finger', 579),
#  ('palate', 576),
#  ('hint', 568),
#  ('abv', 567),
#  ('hop', 556),
#  ('complex', 554),
#  ('sour', 552),
#  ('also', 550),
#  ('retention', 550),
#  ('tart', 546),
#  ('beers', 545),
#  ('smells', 542),
#  ('slight', 538),
#  ('hops', 534),
#  ('touch', 531),
#  ('even', 530),
#  ('way', 525),
#  ('tan', 517),
#  ('ive', 516),
#  ('pineapple', 516),
#  ('time', 513),
#  ('mango', 510),
#  ('pretty', 505),
#  ('soft', 504),
#  ('excellent', 503),
#  ('juicy', 501),
#  ('balance', 501),
#  ('definitely', 501),
#  ('first', 500),
#  ('funk', 497),
#  ('drink', 487),
#  ('fresh', 487),
#  ('strong', 479),
#  ('quickly', 479),
#  ('front', 472),
#  ('deep', 471),
#  ('moderate', 469),
#  ('better', 468),
#  ('roasted', 466),
#  ('lots', 465),
#  ('back', 464),
#  ('super', 461),
#  ('around', 461),
#  ('aromas', 456),
#  ('ipa', 455),
#  ('perfect', 447),
#  ('maple', 444),
#  ('mouth', 442),
#  ('follows', 440),
#  ('style', 440),
#  ('fruits', 436),
#  ('heavy', 435),
#  ('wine', 431),
#  ('mild', 431),
#  ('golden', 430),
#  ('yellow', 423),
#  ('try', 420),
#  ('lot', 419),
#  ('amazing', 419),
#  ('peach', 418),
#  ('malts', 418),
#  ('huge', 409),
#  ('coconut', 408),
#  ('sugar', 408),
#  ('end', 408),
#  ('think', 407),
#  ('could', 406),
#  ('top', 404),
#  ('juice', 402),
#  ('fruity', 401),
#  ('lemon', 399),
#  ('small', 399),
#  ('delicious', 395),
#  ('sticky', 391),
#  ('foam', 389),
#  ('pine', 388),
#  ('ever', 386),
#  ('character', 378),
#  ('long', 378),
#  ('boozy', 378),
#  ('molasses', 376),
#  ('amount', 369),
#  ('cinnamon', 367),
#  ('vintage', 367),
#  ('im', 366),
#  ('brew', 365),
#  ('appearance', 360),
#  ('earthy', 358),
#  ('bright', 357),
#  ('dank', 350),
#  ('opaque', 349),
#  ('right', 347),
#  ('minimal', 346),
#  ('though', 345),
#  ('heat', 344),
#  ('finishes', 344),
#  ('two', 341),
#  ('easy', 340),
#  ('high', 339),
#  ('oz', 339),
#  ('toffee', 338),
#  ('tastes', 338),
#  ('maybe', 336),
#  ('low', 334),
#  ('booze', 334),
#  ('look', 331),
#  ('comes', 331),
#  ('aged', 325),
#  ('love', 324),
#  ('subtle', 324),
#  ('floral', 324),
#  ('solid', 323),
#  ('cocoa', 319),
#  ('base', 318),
#  ('fantastic', 313),
#  ('hints', 311),
#  ('leaves', 311),
#  ('beautiful', 311),
#  ('red', 310),
#  ('got', 310),
#  ('drinking', 309),
#  ('stouts', 309),
#  ('along', 308),
#  ('ring', 308),
#  ('sure', 307),
#  ('worth', 306),
#  ('clear', 305),
#  ('expected', 301),
#  ('side', 300),
#  ('old', 298),
#  ('years', 293),
#  ('another', 291),
#  ('roast', 290),
#  ('lingering', 290),
#  ('fairly', 289),
#  ('tulip', 288),
#  ('yet', 287),
#  ('sip', 286),
#  ('enough', 285),
#  ('cherry', 284),
#  ('thanks', 283),
#  ('snifter', 276),
#  ('drinkable', 276),
#  ('favorite', 275),
#  ('milk', 274),
#  ('without', 274),
#  ('funky', 272),
#  ('canned', 272),
#  ('profile', 271),
#  ('tongue', 271),
#  ('presence', 266),
#  ('complexity', 264),
#  ('hype', 263),
#  ('come', 262),
#  ('syrup', 260),
#  ('theres', 260),
#  ('2', 257),
#  ('note', 257),
#  ('crisp', 257),
#  ('dont', 255),
#  ('tasty', 254),
#  ('pale', 254),
#  ('looks', 254),
#  ('apricot', 252),
#  ('something', 251),
#  ('going', 251),
#  ('green', 250),
#  ('doesnt', 250),
#  ('nicely', 249),
#  ('clean', 248),
#  ('absolutely', 245),
#  ('blend', 242),
#  ('see', 240),
#  ('honey', 239),
#  ('wonderful', 238),
#  ('drank', 237),
#  ('warms', 236),
#  ('tartness', 235),
#  ('less', 235),
#  ('cap', 235),
#  ('2018', 234),
#  ('wood', 234),
#  ('l', 234),
#  ('fudge', 233),
#  ('followed', 233),
#  ('incredible', 233),
#  ('roasty', 232),
#  ('spice', 231),
#  ('makes', 230),
#  ('present', 230),
#  ('fluffy', 229),
#  ('mocha', 228),
#  ('cloudy', 228),
#  ('ba', 228),
#  ('aftertaste', 227),
#  ('ale', 226),
#  ('tons', 226),
#  ('world', 225),
#  ('colored', 224),
#  ('never', 224),
#  ('thing', 224),
#  ('probably', 224),
#  ('batch', 224),
#  ('apple', 223),
#  ('tangerine', 223),
#  ('acidity', 222),
#  ('brewery', 222),
#  ('12', 221),
#  ('everything', 220),
#  ('oily', 219),
#  ('pitch', 218),
#  ('gold', 218),
#  ('hoppy', 218),
#  ('decent', 217),
#  ('say', 217),
#  ('tasting', 217),
#  ('fades', 217),
#  ('bubbles', 216),
#  ('imperial', 216),
#  ('perfectly', 215),
#  ('lightly', 215),
#  ('tap', 214),
#  ('away', 213),
#  ('enjoyable', 213),
#  ('overly', 212),
#  ('toasted', 211),
#  ('forward', 211),
#  ('half', 209),
#  ('dense', 208),
#  ('many', 207),
#  ('viscous', 207),
#  ('lingers', 207),
#  ('date', 205),
#  ('acidic', 203),
#  ('cream', 203),
#  ('spicy', 202),
#  ('make', 202),
#  ('done', 201),
#  ('pleasant', 201),
#  ('know', 201),
#  ('every', 200),
#  ('pepper', 199),
#  ('day', 199),
#  ('looking', 199),
#  ('intense', 198),
#  ('thats', 198),
#  ('silky', 198),
#  ('together', 195),
#  ('version', 195),
#  ('foamy', 195),
#  ('similar', 193),
#  ('amber', 193),
#  ('glad', 193),
#  ('seems', 192),
#  ('warming', 191),
#  ('level', 191),
#  ('malty', 191),
#  ('stone', 191),
#  ('2019', 191),
#  ('plenty', 190),
#  ('wow', 190),
#  ('fingers', 189),
#  ('quality', 189),
#  ('extremely', 188),
#  ('fine', 188),
#  ('2017', 188),
#  ('find', 187),
#  ('id', 187),
#  ('outstanding', 187),
#  ('herbal', 186),
#  ('awesome', 185),
#  ('cherries', 185),
#  ('last', 185),
#  ('far', 184),
#  ('bite', 184),
#  ('ipas', 184),
#  ('want', 183),
#  ('brings', 183),
#  ('hard', 183),
#  ('3', 183),
#  ('burn', 182),
#  ('somewhat', 181),
#  ('2016', 181),
#  ('chewy', 181),
#  ('getting', 180),
#  ('burnt', 180),
#  ('incredibly', 179),
#  ('faint', 179),
#  ('lace', 179),
#  ('nothing', 179),
#  ('experience', 178),
#  ('frothy', 178),
#  ('dissipates', 177),
#  ('bottled', 177),
#  ('coming', 177),
#  ('year', 176),
#  ('hot', 176),
#  ('class', 176),
#  ('nearly', 176),
#  ('real', 175),
#  ('tasted', 174),
#  ('melon', 174),
#  ('enjoyed', 174),
#  ('grape', 173),
#  ('oil', 173),
#  ('made', 173),
#  ('point', 173),
#  ('leaving', 172),
#  ('tried', 172),
#  ('new', 172),
#  ('murky', 170),
#  ('lacings', 170),
#  ('tobacco', 170),
#  ('might', 170),
#  ('4', 169),
#  ('yeast', 169),
#  ('review', 168),
#  ('house', 168),
#  ('carb', 167),
#  ('2020', 167),
#  ('may', 166),
#  ('finally', 166),
#  ('piney', 166),
#  ('isnt', 166),
#  ('raisin', 165),
#  ('certainly', 165),
#  ('warm', 165),
#  ('sourness', 164),
#  ('leather', 163),
#  ('take', 162),
#  ('raspberry', 162),
#  ('1', 162),
#  ('inch', 161),
#  ('mostly', 160),
#  ('bold', 160),
#  ('actually', 159),
#  ('enjoy', 159),
#  ('highly', 159),
#  ('gets', 159),
#  ('char', 158),
#  ('slowly', 158),
#  ('refreshing', 157),
#  ('depth', 157),
#  ('double', 156),
#  ('served', 156),
#  ('dated', 156),
#  ('raisins', 155),
#  ('licorice', 155),
#  ('different', 155),
#  ('tree', 155),
#  ('dipa', 154),
#  ('5', 153),
#  ('cant', 153),
#  ('left', 153),
#  ('haze', 153),
#  ('go', 152),
#  ('kind', 152),
#  ('ripe', 151),
#  ('didnt', 151),
#  ('grass', 151),
#  ('truly', 151),
#  ('16', 150),
#  ('mix', 149),
#  ('lighter', 149),
#  ('surprisingly', 148),
#  ('jet', 148),
#  ('goes', 147),
#  ('middle', 146),
#  ('zest', 145),
#  ('texture', 144),
#  ('stuff', 144),
#  ('straw', 144),
#  ('pint', 142),
#  ('trillium', 142),
#  ('slick', 141),
#  ('syrupy', 141),
#  ('bomb', 140),
#  ('ml', 140),
#  ('dried', 139),
#  ('rather', 139),
#  ('hay', 139),
#  ('wish', 138),
#  ('sharp', 138),
#  ('grassy', 138),
#  ('rind', 138),
#  ('things', 137),
#  ('especially', 136),
#  ('classic', 136),
#  ('carbonated', 135),
#  ('damn', 135),
#  ('adds', 135),
#  ('khaki', 134),
#  ('papaya', 134),
#  ('starts', 134),
#  ('wild', 133),
#  ('feels', 133),
#  ('although', 132),
#  ('unique', 131),
#  ('easily', 130),
#  ('offwhite', 130),
#  ('candy', 130),
#  ('expect', 130),
#  ('whiskey', 130),
#  ('espresso', 130),
#  ('barnyard', 130),
#  ('bread', 129),
#  ('neipa', 129),
#  ('interesting', 129),
#  ('throughout', 129),
#  ('citrusy', 128),
#  ('oaky', 128),
#  ('wet', 128),
#  ('barrels', 127),
#  ('regular', 126),
#  ('moderately', 126),
#  ('perhaps', 126),
#  ('pink', 125),
#  ('750ml', 125),
#  ('motor', 125),
#  ('resin', 125),
#  ('always', 124),
#  ('bad', 124),
#  ('flavorful', 124),
#  ('anything', 123),
#  ('background', 123),
#  ('cloying', 123),
#  ('charred', 123),
#  ('16oz', 122),
#  ('drinks', 122),
#  ('close', 122),
#  ('collar', 122),
#  ('velvety', 121),
#  ('behind', 121),
#  ('f', 121),
#  ('peel', 121),
#  ('typical', 120),
#  ('ruby', 120),
#  ('age', 120),
#  ('liquid', 120),
#  ('found', 120),
#  ('impressive', 120),
#  ('lovely', 120),
#  ('hits', 120),
#  ('give', 119),
#  ('candied', 119),
#  ('lambic', 119),
#  ('fizzy', 119),
#  ('however', 119),
#  ('hill', 119),
#  ('hit', 119),
#  ('prominent', 118),
#  ('resinous', 118),
#  ('must', 117),
#  ('woody', 117),
#  ('completely', 117),
#  ('hidden', 117),
#  ('dessert', 116),
#  ('least', 115),
#  ('shared', 115),
#  ('loads', 115),
#  ('near', 115),
#  ('start', 115),
#  ('ago', 115),
#  ('average', 114),
#  ('next', 114),
#  ('release', 114),
#  ('edge', 114),
#  ('aging', 113),
#  ('second', 113),
#  ('settles', 113),
#  ('said', 113),
#  ('edges', 113),
#  ('decadent', 113),
#  ('heads', 113),
#  ('large', 112),
#  ('cellar', 112),
#  ('days', 112),
#  ('noticeable', 112),
#  ('wasnt', 111),
#  ('else', 111),
#  ('bubbly', 111),
#  ('given', 111),
#  ('hue', 110),
#  ('upfront', 110),
#  ('porter', 110),
#  ('lime', 110),
#  ('massive', 109),
#  ('price', 109),
#  ('fan', 109),
#  ('initial', 109),
#  ('prefer', 109),
#  ('share', 108),
#  ('short', 108),
#  ('draft', 108),
#  ('treat', 108),
#  ('since', 108),
#  ('smoke', 107),
#  ('ton', 107),
#  ('cake', 107),
#  ('10', 107),
#  ('sweeter', 107),
#  ('consumed', 107),
#  ('warmth', 106),
#  ('rating', 106),
#  ('across', 106),
#  ('straight', 106),
#  ('able', 106),
#  ('put', 105),
#  ('despite', 104),
#  ('citra', 104),
#  ('thought', 104),
#  ('plum', 104),
#  ('peppery', 104),
#  ('vinegar', 103),
#  ('special', 103),
#  ('takes', 103),
#  ('layer', 102),
#  ('guava', 102),
#  ('immediately', 101),
#  ('round', 101),
#  ('bready', 101),
#  ('12oz', 101),
#  ('mildly', 101),
#  ('“', 100),
#  ('nutty', 100),
#  ('offering', 100),
#  ('wheat', 100),
#  ('delicate', 99),
#  ('”', 99),
#  ('overwhelming', 99),
#  ('cold', 98),
#  ('coating', 98),
#  ('overpowering', 98),
#  ('dryness', 98),
#  ('teku', 98),
#  ('opens', 98),
#  ('mellow', 97),
#  ('brett', 97),
#  ('whole', 97),
#  ('sipper', 97),
#  ('2015', 96),
#  ('barleywine', 96),
#  ('west', 96),
#  ('backbone', 96),
#  ('reminds', 96),
#  ('musty', 95),
#  ('coats', 95),
#  ('bar', 95),
#  ('keep', 95),
#  ('saison', 95),
#  ('part', 95),
#  ('plus', 95),
#  ('6', 94),
#  ('type', 94),
#  ('three', 94),
#  ('effervescence', 94),
#  ('swallow', 94),
#  ('couple', 93),
#  ('coast', 93),
#  ('mixed', 93),
#  ('chili', 93),
#  ('pure', 92),
#  ('rum', 92),
#  ('flavour', 92),
#  ('bottles', 91),
#  ('others', 90),
#  ('aggressive', 90),
#  ('bottom', 90),
#  ('months', 90),
#  ('trying', 90),
#  ('gentle', 90),
#  ('beige', 89),
#  ('grain', 89),
#  ('drying', 89),
#  ('farmstead', 89),
#  ('buy', 88),
#  ('believe', 88),
#  ('tiny', 88),
#  ('either', 88),
#  ('need', 88),
#  ('let', 88),
#  ('opened', 88),
#  ('dates', 87),
#  ('gives', 87),
#  ('vinous', 87),
#  ('held', 87),
#  ('linger', 87),
#  ('dankness', 87),
#  ('add', 87),
#  ('lactic', 87),
#  ('layers', 86),
#  ('original', 86),
#  ('friend', 86),
#  ('chance', 86),
#  ('honestly', 86),
#  ('american', 85),
#  ('raspberries', 85),
#  ('picked', 85),
#  ('recedes', 85),
#  ('booziness', 85),
#  ('fig', 84),
#  ('crazy', 84),
#  ('expecting', 84),
#  ('room', 84),
#  ('due', 83),
#  ('pith', 83),
#  ('fair', 82),
#  ('brandy', 82),
#  ('compared', 82),
#  ('soapy', 82),
#  ('peaches', 82),
#  ('robust', 82),
#  ('ne', 82),
#  ('leave', 81),
#  ('project', 81),
#  ('marshmallow', 81),
#  ('fruited', 81),
#  ('exactly', 81),
#  ('lasting', 81),
#  ('towards', 81),
#  ('times', 80),
#  ('drinkability', 80),
#  ('example', 80),
#  ('figs', 79),
#  ('added', 79),
#  ('grapes', 79),
#  ('night', 79),
#  ('purchased', 79),
#  ('pithy', 78),
#  ('earthiness', 78),
#  ('came', 78),
#  ('upon', 78),
#  ('work', 78),
#  ('spotty', 78),
#  ('line', 78),
#  ('subdued', 78),
#  ('muted', 78),
#  ('apricots', 77),
#  ('pick', 77),
#  ('oh', 77),
#  ('beautifully', 77),
#  ('hf', 76),
#  ('lively', 76),
#  ('nuts', 76),
#  ('happy', 76),
#  ('pillowy', 76),
#  ('toasty', 76),
#  ('open', 75),
#  ('wait', 75),
#  ('cut', 75),
#  ('punch', 75),
#  ('making', 75),
#  ('phenomenal', 75),
#  ('seem', 74),
#  ('spices', 74),
#  ('somehow', 74),
#  ('colour', 74),
#  ('sugary', 74),
#  ('impressed', 73),
#  ('belgian', 73),
#  ('works', 73),
#  ('exceptional', 73),
#  ('earth', 73),
#  ('tones', 73),
#  ('standard', 73),
#  ('750', 73),
#  ('seek', 72),
#  ('loved', 72),
#  ('oranges', 72),
#  ('8', 72),
#  ('nectarine', 72),
#  ('simply', 72),
#  ('brownie', 72),
#  ('cantillon', 71),
#  ('integrated', 71),
#  ('label', 71),
#  ('pungent', 71),
#  ('visible', 71),
#  ('shows', 70),
#  ('mind', 70),
#  ('passion', 70),
#  ('combination', 70),
#  ('2014', 70),
#  ('home', 70),
#  ('topped', 70),
#  ('people', 70),
#  ('bean', 70),
#  ('used', 70),
#  ('weeks', 70),
#  ('adjuncts', 70),
#  ('warmed', 70),
#  ('goodness', 70),
#  ('darker', 70),
#  ('ice', 69),
#  ('past', 69),
#  ('ill', 69),
#  ('berry', 69),
#  ('prickly', 69),
#  ('grains', 69),
#  ('peppers', 68),
#  ('passionfruit', 68),
#  ('bring', 68),
#  ('luscious', 68),
#  ('liked', 68),
#  ('sort', 68),
#  ('effervescent', 68),
#  ('elements', 67),
#  ('residual', 67),
#  ('addition', 67),
#  ('guess', 67),
#  ('true', 67),
#  ('15', 67),
#  ('mosaic', 67),
#  ('opinion', 67),
#  ('surprised', 67),
#  ('sours', 67),
#  ('list', 67),
#  ('took', 67),
#  ('live', 67),
#  ('lives', 67),
#  ('highlights', 67),
#  ('lactose', 66),
#  ('show', 66),
#  ('barely', 66),
#  ('impression', 66),
#  ('cola', 66),
#  ('2021', 66),
#  ('barley', 66),
#  ('pear', 66),
#  ('wonderfully', 66),
#  ('relatively', 66),
#  ('barrelaged', 66),
#  ('form', 66),
#  ('reviewed', 65),
#  ('king', 65),
#  ('bittersweet', 65),
#  ('midpalate', 65),
#  ('legs', 64),
#  ('sticks', 64),
#  ('dominate', 64),
#  ('45', 64),
#  ('excited', 64),
#  ('several', 63),
#  ('degrees', 63),
#  ('sips', 63),
#  ('pop', 63),
#  ('hope', 63),
#  ('felt', 63),
#  ('cans', 63),
#  ('fruitiness', 63),
#  ('week', 63),
#  ('remains', 63),
#  ('superb', 63),
#  ('scent', 63),
#  ('feeling', 63),
#  ('berries', 63),
#  ('hands', 63),
#  ('rings', 62),
#  ('seen', 62),
#  ('beans', 62),
#  ('trade', 62),
#  ('reddish', 62),
#  ('case', 62),
#  ('strawberry', 62),
#  ('blended', 62),
#  ('thinner', 62),
#  ('sharing', 61),
#  ('harsh', 61),
#  ('tell', 61),
#  ('adding', 61),
#  ('film', 61),
#  ('rated', 61),
#  ('already', 61),
#  ('available', 61),
#  ('growler', 61),
#  ('carbonationo', 61),
#  ('disappointed', 61),
#  ('galaxy', 60),
#  ('leads', 60),
#  ('acid', 60),
#  ('13', 60),
#  ('place', 60),
#  ('face', 60),
#  ('finishing', 60),
#  ('simple', 60),
#  ('bomber', 60),
#  ('stands', 60),
#  ('single', 60),
#  ('slow', 60),
#  ('semidry', 59),
#  ('use', 59),
#  ('mediumlight', 59),
#  ('fridge', 59),
#  ('kick', 59),
#  ('among', 59),
#  ('dissipated', 59),
#  ('usually', 59),
#  ('becomes', 59),
#  ('rye', 59),
#  ('ends', 59),
#  ('ales', 59),
#  ('yes', 58),
#  ('cheers', 58),
#  ('friends', 58),
#  ('otherwise', 58),
#  ('initially', 58),
#  ('instead', 58),
#  ('blanket', 58),
#  ('bought', 58),
#  ('reduces', 58),
#  ('hides', 58),
#  ('batter', 58),
#  ('100', 57),
#  ('thicker', 57),
#  ('carbonationoverall', 57),
#  ('de', 57),
#  ('fully', 57),
#  ('spiciness', 57),
#  ('pronounced', 57),
#  ('hell', 57),
#  ('375', 57),
#  ('astringent', 57),
#  ('characteristics', 57),
#  ('purple', 57),
#  ('wouldnt', 57),
#  ('surface', 57),
#  ('courtesy', 57),
#  ('offerings', 57),
#  ('remember', 57),
#  ('modest', 57),
#  ('expectations', 57),
#  ('worthy', 56),
#  ('underneath', 56),
#  ('skin', 56),
#  ('375ml', 56),
#  ('lower', 56),
#  ('england', 56),
#  ('brewing', 56),
#  ('forms', 56),
#  ('jam', 56),
#  ('higher', 56),
#  ('spot', 56),
#  ('later', 56),
#  ('rest', 56),
#  ('headsmell', 55),
#  ('sides', 55),
#  ('variant', 55),
#  ('aromatic', 55),
#  ('th', 55),
#  ('quick', 55),
#  ('wanted', 55),
#  ('tangy', 55),
#  ('250', 55),
#  ('copper', 55),
#  ('recent', 55),
#  ('stronger', 55),
#  ('pastry', 55),
#  ('undertones', 55),
#  ('follow', 55),
#  ('man', 54),
#  ('considering', 54),
#  ('late', 54),
#  ('dominant', 54),
#  ('cacao', 54),
#  ('guys', 54),
#  ('raw', 54),
#  ('mediumfull', 54),
#  ('gorgeous', 54),
#  ('sense', 54),
#  ('thank', 54),
#  ('course', 54),
#  ('yeasty', 54),
#  ('fullbodied', 54),
#  ('ounce', 54),
#  ('tad', 54),
#  ('restrained', 54),
#  ('absolute', 54),
#  ('tannins', 54),
#  ('recommend', 53),
#  ('sitting', 53),
#  ('2013', 53),
#  ('milky', 53),
#  ('mahogany', 53),
#  ('potent', 53),
#  ('plums', 53),
#  ('inky', 53),
#  ('firm', 53),
#  ('bakers', 53),
#  ('cheese', 53),
#  ('puckering', 53),
#  ('tall', 53),
#  ('rounded', 53),
#  ('lacingaroma', 52),
#  ('distinct', 52),
#  ('treehouse', 52),
#  ('qualities', 52),
#  ('youre', 52),
#  ('jammy', 52),
#  ('powder', 52),
#  ('smelling', 52),
#  ('flat', 52),
#  ('thickness', 52),
#  ('pouring', 52),
#  ('pack', 52),
#  ('lacking', 52),
#  ('14', 52),
#  ('gueuze', 52),
#  ('creaminess', 51),
#  ('brewed', 51),
#  ('bacon', 51),
#  ('inviting', 51),
#  ('atop', 51),
#  ('fuzzy', 51),
#  ('often', 51),
#  ('tannic', 51),
#  ('champagne', 51),
#  ('soon', 51),
#  ('temp', 51),
#  ('taking', 50),
#  ('went', 50),
#  ('smoky', 50),
#  ('water', 50),
#  ('overripe', 50),
#  ('aspect', 50),
#  ...]

# %% [markdown]
# #### Three attributes of the product that are important to the customer: Fruity, Balanced, Robust

# %%
# this dataframe will be used for Task F
df_f = df.copy()

# this dataframe will be used for Task G
df_g = df.copy()

# %% [markdown]
# # Task C

# %%
# three attributes that we chose as input
attributes = ['fruity', 'balanced', 'robust']

# join the clean_review column
def join_words(comment):
    return " ".join(comment)
df['join_review'] = df['clean_review'].map(join_words)

# join the attributes into one string
input_attributes = " ".join(attributes)

# %%
# cosine similarity with bag of words
def bow_similarity(comments):
    documents = [input_attributes, comments]
    count_vectorizer = CountVectorizer()
    sparse_matrix = count_vectorizer.fit_transform(documents)
    doc_term_matrix = sparse_matrix.todense()
    temp_df = pd.DataFrame(doc_term_matrix, columns=count_vectorizer.get_feature_names(), index=['x', 'y'])
    return cosine_similarity(temp_df, temp_df)[0, 1]

df["similarity_score"] = df['join_review'].apply(bow_similarity)

# %%
# create another version of the table for the output
df_c = df.copy()
df_c = df.drop(['clean_review', 'join_review', 'user_rating'], axis=1)

# sort values according to the similarity score
df_c.sort_values(by='similarity_score', ascending=False)
# Out:
#                                         product_name  \
# 4054           Galaxy Dry Hopped Fort Point Pale Ale
# 2512                                           Abner
# 5497                                 Duck Duck Gooze
# 4453                                  Peche 'n Brett
# 16                           Oude Geuze Golden Blend
# ...                                              ...
# 2280                                         Hommage
# 2279  Hunahpu's Imperial Stout - Bourbon Barrel-Aged
# 2278  Hunahpu's Imperial Stout - Bourbon Barrel-Aged
# 2277                         Wide Awake It's Morning
# 6226                                      Black Gold
#
#                                          product_review  similarity_score
# 4054  11/2014 - Wow, this is amazing; incredible aro...          0.264906
# 2512  Tasted from can. Pours a hazy gold. Huge citru...          0.264906
# 5497  On tap at Beavertown Extravaganza. Aroma has s...          0.258199
# 4453  One of the 14 beers we have had in one session...          0.246183
# 16    2014 vintage; drank 6/22/19 @ Golgi Apparatus....          0.240772
# ...                                                 ...               ...
# 2280  Blend 40 Season 17/18. Bottled on March 22, 20...          0.000000
# 2279  2017 release (El Cat Round 7).A: Pours a visco...          0.000000
# 2278  22 oz bomber gifted from Donald and poured int...          0.000000
# 2277  Dark with a rich creamy tan head. Smells of co...          0.000000
# 6226  16, 17.Big barrel presence. Chocolate, fudge, ...          0.000000
#
# [6227 rows x 3 columns]

# %% [markdown]
# # Task D

# %%
# performing sentiment analysis
sia = SentimentIntensityAnalyzer()
df['scores'] = df['product_review'].apply(lambda review: sia.polarity_scores(review))
df['sentiment_score']  = df['scores'].apply(lambda score_dict: score_dict['compound'])

# create another version of the table for the output
df_d = df.copy()
df_d = df_d.drop(['clean_review', 'join_review', 'similarity_score'], axis=1)

# sort values according to the sentiment score
df_d.sort_values(by='sentiment_score', ascending=False)
# Out:
#                                   product_name  \
# 5957                           Mornin' Delight
# 6073                                   Abraxas
# 1828                           Cable Car Kriek
# 3070                                  No Rules
# 14                                   The Peach
# ...                                        ...
# 186   Ghost In The Machine - Double Dry-Hopped
# 99                              Leche Borracho
# 4278                             Black Tuesday
# 4889                          Fuzzy Baby Ducks
# 3721                           Double Sunshine
#
#                                          product_review  user_rating  \
# 5957  An unbelievably huge thanks to Chris for this ...         4.56
# 6073  16 oz. Cup (From On-Tap/Beer To Go)From: The A...         4.75
# 1828  Brown glass bottle served into a wine glass at...         4.42
# 3070  Jan 2021 New Years Day2019 vintage from pint g...         4.82
# 14    one of the beers i have been after for a long ...         4.45
# ...                                                 ...          ...
# 186   Currently ranked #24 in the Top New England IP...         3.46
# 99    On tap at Hollingshead’s in Orange, CA.Oh my s...         4.49
# 4278  Received from @2beerdogs in NBS BIF 10 – Thank...         3.94
# 4889  Poured out of a can into a tree house pint gla...         4.19
# 3721  Pint can - dated 04/30/20 - poured into an IPA...         4.32
#
#                                                  scores  sentiment_score
# 5957  {'neg': 0.041, 'neu': 0.703, 'pos': 0.256, 'co...           0.9992
# 6073  {'neg': 0.0, 'neu': 0.731, 'pos': 0.269, 'comp...           0.9992
# 1828  {'neg': 0.038, 'neu': 0.69, 'pos': 0.272, 'com...           0.9992
# 3070  {'neg': 0.028, 'neu': 0.683, 'pos': 0.289, 'co...           0.9991
# 14    {'neg': 0.037, 'neu': 0.691, 'pos': 0.272, 'co...           0.9991
# ...                                                 ...              ...
# 186   {'neg': 0.168, 'neu': 0.731, 'pos': 0.102, 'co...          -0.9421
# 99    {'neg': 0.287, 'neu': 0.609, 'pos': 0.104, 'co...          -0.9449
# 4278  {'neg': 0.11, 'neu': 0.835, 'pos': 0.055, 'com...          -0.9584
# 4889  {'neg': 0.318, 'neu': 0.631, 'pos': 0.051, 'co...          -0.9659
# 3721  {'neg': 0.154, 'neu': 0.704, 'pos': 0.142, 'co...          -0.9677
#
# [6227 rows x 5 columns]

# %% [markdown]
# # Task E

# %%
# created another dataframe for aggregating the similarity scores and sentiment scores
output = df.groupby(['product_name'])['similarity_score', 'sentiment_score'].mean()

# calculated the evaluation scores
output['evaluation_score'] = output['similarity_score'] + output['sentiment_score']
output
# Out:
#                                          similarity_score  sentiment_score  \
# product_name
# A Deal With The Devil                            0.011443         0.699264
# A Deal With The Devil - Double Oak-Aged          0.008051         0.841796
# Aaron                                            0.004800         0.829384
# Abner                                            0.036676         0.864592
# Abrasive Ale                                     0.018156         0.766700
# ...                                                   ...              ...
# Westly                                           0.028731         0.761940
# Wide Awake It's Morning                          0.019441         0.627304
# Zenne Y Frontera                                 0.042271         0.874504
# Zombie Dust                                      0.028963         0.796480
# §ucaba                                           0.025585         0.765412
#
#                                          evaluation_score
# product_name
# A Deal With The Devil                            0.710707
# A Deal With The Devil - Double Oak-Aged          0.849847
# Aaron                                            0.834184
# Abner                                            0.901268
# Abrasive Ale                                     0.784856
# ...                                                   ...
# Westly                                           0.790671
# Wide Awake It's Morning                          0.646745
# Zenne Y Frontera                                 0.916775
# Zombie Dust                                      0.825443
# §ucaba                                           0.790997
#
# [250 rows x 3 columns]

# %%
output.sort_values(by='evaluation_score', ascending=False)[0:3]
# Out:
#                                            similarity_score  sentiment_score  \
# product_name
# Cable Car Kriek                                    0.024023         0.930252
# Cable Car                                          0.024918         0.904408
# Genealogy Of Morals - Bourbon Barrel-Aged          0.015748         0.902328
#
#                                            evaluation_score
# product_name
# Cable Car Kriek                                    0.954275
# Cable Car                                          0.929326
# Genealogy Of Morals - Bourbon Barrel-Aged          0.918076

# %% [markdown]
# #### The top 3 products are 'Cable Car Kriek', 'Cable Car', 'Genealogy of Morals - Bourbon Barrel-Aged'.

# %% [markdown]
# # Task F - Part 1

# %% [markdown]
# ### Cosine similarity using word vectors

# %%
# using word vectors to calculate the similarities instead of bag-of-words
nlp = en_core_web_lg.load()
def cosine_similarity(comment):
    base = nlp(comment)
    compare = nlp(input_attributes)
    return base.similarity(compare)

# %%
# join the words from the clean_review column
def join_words(comment):
    return " ".join(comment)
df_f['join_review'] = df_f['clean_review'].map(join_words)

# %%
# the three attributes we chose in Task B
attributes = ['fruity', 'balanced', 'robust']
input_attributes = " ".join(attributes)

# getting the similarity scores
df_f['similarity_score'] = df_f['join_review'].map(cosine_similarity)

# %%
# this output shows the similarity scores calculated using word vectors
output_df = df_f[['product_name', 'product_review', 'similarity_score']]

# %%
# sentiment analysis on the product_review (performed this again because we are using a different dataframe)
sia = SentimentIntensityAnalyzer()
df_f['scores'] = df_f['product_review'].apply(lambda review: sia.polarity_scores(review))
df_f['sentiment_score']  = df_f['scores'].apply(lambda score_dict: score_dict['compound'])
df_f.sort_values(by='sentiment_score', ascending=False)

# create another version of the table for the output
output_f = df.copy()
output_f = output_f.drop(['clean_review', 'join_review', 'similarity_score'], axis=1)

# sort values according to the sentiment score
#output_f.sort_values(by='sentiment_score', ascending=False)

# %%
# created another dataframe for aggregating the similarity scores and sentiment scores
output_f1 = df_f.groupby(['product_name'])['similarity_score', 'sentiment_score'].mean()

# calculated the evaluation scores
output_f1['evaluation_score'] = output_f1['similarity_score'] + output_f1['sentiment_score']
output_f1
# Out:
#                                          similarity_score  sentiment_score  \
# product_name
# A Deal With The Devil                            0.637332         0.699264
# A Deal With The Devil - Double Oak-Aged          0.639584         0.841796
# Aaron                                            0.647567         0.829384
# Abner                                            0.656574         0.864592
# Abrasive Ale                                     0.671344         0.766700
# ...                                                   ...              ...
# Westly                                           0.662809         0.761940
# Wide Awake It's Morning                          0.637323         0.627304
# Zenne Y Frontera                                 0.682039         0.874504
# Zombie Dust                                      0.659182         0.796480
# §ucaba                                           0.645563         0.765412
#
#                                          evaluation_score
# product_name
# A Deal With The Devil                            1.336596
# A Deal With The Devil - Double Oak-Aged          1.481380
# Aaron                                            1.476951
# Abner                                            1.521166
# Abrasive Ale                                     1.438044
# ...                                                   ...
# Westly                                           1.424749
# Wide Awake It's Morning                          1.264627
# Zenne Y Frontera                                 1.556543
# Zombie Dust                                      1.455662
# §ucaba                                           1.410975
#
# [250 rows x 3 columns]

# %%
# top products
output_f1.sort_values(by='evaluation_score', ascending=False)[0:3]
# Out:
#                   similarity_score  sentiment_score  evaluation_score
# product_name
# Cable Car Kriek           0.658513         0.930252          1.588765
# Flora Plum                0.680517         0.890092          1.570609
# Zenne Y Frontera          0.682039         0.874504          1.556543

# %% [markdown]
# #### New top products are 'Cable Car Kriek', 'Flora Plum', and 'Zenne Y Frontera'.

# %% [markdown]
# # Task F - Part 2 (% of reviews)

# %%
attributes = ['fruity', 'balanced', 'robust']

# creating columns for each attribute
for attribute in attributes:
    df['contains_' + attribute] = 0

# replacing 0s with 1s for reviews that mention the attributes
for i in range(len(df['join_review'])):
    for attribute in attributes:
        if attribute in df['join_review'][i]:
            df['contains_' + attribute][i] = 1

# %%
# calculate the proportions of reviews that mention the attributes for each product
contain_df = df.groupby(['product_name'])['similarity_score','sentiment_score','contains_fruity', 'contains_balanced', 'contains_robust'].mean()
contain_df['evaluation_score'] = contain_df['similarity_score'] + contain_df['sentiment_score']

# %%
# merge two dataframes so that we can efficiently compare similarity scores calculated using two different methods
comparison_df = contain_df.merge(output_f1, left_on = 'product_name', right_on = 'product_name', suffixes=('_bow', '_vec'))

# %% [markdown]
# ### Comparison between evaluation scores and % of mentions
# ### Sorted by bag-of-words evaluation scores

# %%
# sort the comparison dataframe using the bag-of-words evaluation score
comparison_df1 = comparison_df.drop(['similarity_score_bow','similarity_score_vec','sentiment_score_bow','sentiment_score_vec'], axis=1)
comparison_df1.sort_values(by='evaluation_score_bow', ascending=False)[0:3]
# Out:
#                                            contains_fruity  contains_balanced  \
# product_name
# Cable Car Kriek                                       0.28               0.12
# Cable Car                                             0.12               0.16
# Genealogy Of Morals - Bourbon Barrel-Aged             0.04               0.12
#
#                                            contains_robust  \
# product_name
# Cable Car Kriek                                       0.04
# Cable Car                                             0.00
# Genealogy Of Morals - Bourbon Barrel-Aged             0.04
#
#                                            evaluation_score_bow  \
# product_name
# Cable Car Kriek                                        0.954275
# Cable Car                                              0.929326
# Genealogy Of Morals - Bourbon Barrel-Aged              0.918076
#
#                                            evaluation_score_vec
# product_name
# Cable Car Kriek                                        1.588765
# Cable Car                                              1.514330
# Genealogy Of Morals - Bourbon Barrel-Aged              1.544946

# %% [markdown]
# ### Comparison between evaluation scores and % of mentions
# ### Sorted by word vector evaluation scores

# %%
# sort the comparison dataframe using the word vector evaluation score
comparison_df1.sort_values(by='evaluation_score_vec', ascending=False)[0:3]
# Out:
#                   contains_fruity  contains_balanced  contains_robust  \
# product_name
# Cable Car Kriek              0.28               0.12             0.04
# Flora Plum                   0.20               0.16             0.00
# Zenne Y Frontera             0.20               0.28             0.00
#
#                   evaluation_score_bow  evaluation_score_vec
# product_name
# Cable Car Kriek               0.954275              1.588765
# Flora Plum                    0.912830              1.570609
# Zenne Y Frontera              0.916775              1.556543

# %% [markdown]
# If we use word vectors for the cosine similarity calculation, we see that our top product (Cable Car Kriek) stays the same however, the other two products change. Flora Plum and Zenne Y Frontera are now second and third place respectively. Overall, as shown in the two comparison tables above, the proportion of each product's reviews mentioning the attribute is higher when we use word vectors to calculate cosine similarity.

# %% [markdown]
# # Task G

# %%
# calculate the average user ratings for each product
df_g1 = df_g.groupby(['product_name'])['user_rating'].mean()
df_g1 = pd.DataFrame(df_g1)

# extract the top 3 products
df_g1.sort_values(by='user_rating', ascending=False)[0:3]
# Out:
#                        user_rating
# product_name
# Chemtrailmix               4.77160
# Vanilla Bean Assassin      4.74625
# Blessed                    4.74280

# %%
# extract the similarity scores, sentiment scores, evaluation scores, and proportions for the top 3
comp_df = comparison_df.loc[['Chemtrailmix', 'Vanilla Bean Assassin', 'Blessed']]
comp_df = comp_df.drop(['similarity_score_vec','sentiment_score_vec', 'evaluation_score_vec'], axis=1)
comp_df
# Out:
#                        similarity_score_bow  sentiment_score_bow  \
# product_name
# Chemtrailmix                       0.019334             0.791708
# Vanilla Bean Assassin              0.006481             0.812306
# Blessed                            0.016703             0.739048
#
#                        contains_fruity  contains_balanced  contains_robust  \
# product_name
# Chemtrailmix                       0.0             0.2000              0.0
# Vanilla Bean Assassin              0.0             0.0625              0.0
# Blessed                            0.0             0.2000              0.0
#
#                        evaluation_score_bow
# product_name
# Chemtrailmix                       0.811042
# Vanilla Bean Assassin              0.818787
# Blessed                            0.755751

# %% [markdown]
# If we ignored the similarity and feature sentiment scores and simply chose the 3 products based on average user ratings, we got a completely different combination of products: 'Chemtrailmix', 'Vanilla Bean Assassin', and 'Blessed'. Using the similarity scores calculated with bag-of-words, these products will not meet the requirements of the user looking for recommendations. Although the sentiment scores are high, the similarity scores of the three products against the selected attributes are very low. This could mean that there are positive reviews on the three products based on other attributes. As shown in the table, the proportions of each of the attributes in the three products are very low. There are no mentions for each of the products about the 'Fruity' and 'Robust' attributes. Therefore, this set of recommendations will not satisfy the customer's needs.
